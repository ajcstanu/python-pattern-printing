# %%
print("*"*5)
# Out:
# *****

# %%
n=5
for j in range(n):
    print("*")
# Out:
# *
# *
# *
# *
# *

# %%
n=5
for j in  range(n):
    print("*",end="")
# Out:
# *****

# %%
n=5
for k in range(n):
    for j in range (n):
        print("*", end="")
# Out:
# *************************

# %%
n=5
for k in range(n): #row
    for j in range (n):#columns
        print("*", end="")
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
n=5
for i in range(n):
    for k in range(i+1):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range(n):
    for j in range(i,n):#starting and ending point 
        print("*", end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
n=5
for i in range(n):
    for j in range(i,n):
        print(" ", end="")
    for k in range(i+1):
        print("*",end="")
    print()
# Out:
#      *
#     **
#    ***
#   ****
#  *****

# %%
n=5
for i in range(n):
    for j in range(i,n):
        print(" ",end="")
    for k in range(i,n):
        print("*",end="")
    print()
# Out:
#      *****
#     ****
#    ***
#   **
#  *

# %%
n=5
for i in range(n):
    for j in range(i+1):
      print("",end="")
    for k in range(i,n):
        print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
n = 5
for i in range(n):
    for j in range(i):
        print(" ", end="")         # Print leading spaces
    for k in range(i, n):
        print("*", end="")         # Print stars
    print()                        # New line
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
n=5
for i in range(n):
    for j in range(i,n):
        print(" ", end="")
    for k in range(i):
        print("*",end="")
    for l in range(i+1):
        print("*",end="")
    print()
# Out:
#      *
#     ***
#    *****
#   *******
#  *********

# %%
n=5
for i in range(n):
    for j in range(i+1):
        print(" ",end="")
    for k in range(i,n):
        print("*",end="")
    for l in range(i+1,n):
        print("*",end="")
    
    print()
# Out:
#  *********
#   *******
#    *****
#     ***
#      *
